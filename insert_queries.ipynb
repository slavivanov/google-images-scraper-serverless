# %%
from lib.query_persistence_dynamo import QueryPersistenceDynamo

persister = QueryPersistenceDynamo()
# Out:
# Storage found.

# %% [markdown]
# Read the queries

# %%
queries = []
with open('categories.txt') as file:
    for line in file:
        queries.append(line.rstrip())
    

queries
# Out:
# ['Alfa-Romeo Alfa 155',
#  'Alfa-Romeo Alfa 156',
#  'Alfa-Romeo Alfa 147',
#  'Alfa-Romeo Alfa 166',
#  'Alfa-Romeo Alfa 146',
#  'Alfa-Romeo Alfa 159',
#  'Alfa-Romeo GTV',
#  'Alfa-Romeo Alfa 145',
#  'Aprilia Shiver',
#  'Aprilia SR Motorad',
#  'Audi 80',
#  'Audi A4/S4',
#  'Audi A3/S3',
#  'Audi A6/S6',
#  'Audi 100',
#  'Audi A8/S8',
#  'Audi Coupe',
#  'Audi A2',
#  'Audi Q7',
#  'Audi A5/S5',
#  'Audi 90',
#  'Audi TT',
#  'A4/S4',
#  'Audi Q5',
#  'BMW Series 3',
#  'BMW Series 5',
#  'BMW Series 1',
#  'BMW X5',
#  'BMW K',
#  'BMW Series 7',
#  'BMW X6',
#  'BMW R',
#  'BMW X3',
#  'Chevrolet Aveo',
#  'Chevrolet Lacetti',
#  'Chevrolet Malibu',
#  'Chevrolet Epica',
#  'Chevrolet Spark',
#  'Chevrolet Cruze',
#  'Chevrolet Kalos',
#  'Chevrolet Tacuma',
#  'Chevrolet Captiva',
#  'Chevrolet Matiz',
#  'Chevrolet Nubira',
#  'Chevrolet Evanda',
#  'Chevrolet Blazer ST',
#  'Chevrolet TrailBlazer',
#  'Chrysler Voyager',
#  'Chrysler PT Cruiser',
#  'Chrysler Stratus',
#  'Chrysler Town & Country',
#  'Citroen ZX',
#  'Citroen Saxo',
#  'Citroen C3',
#  'Citroen C5',
#  'Citroen C4',
#  'Citroen Berlingo',
#  'Citroen Xsara Picasso',
#  'Citroen C4 Picasso',
#  'Citroen Xantia',
#  'Citroen Xsara',
#  'Citroen C8',
#  'Citroen C2',
#  'Citroen Evasion',
#  'Citroen C1',
#  'Citroen Jumpy',
#  'Citroen Jumper',
#  'Citroen C-Crosser',
#  'Citroen C6',
#  'Citroen DS4',
#  'Dacia Logan',
#  'Dacia Sandero',
#  'Dacia Dokker',
#  'Dacia Lodgy',
#  'Dacia Duster',
#  'Daewoo Lanos',
#  'Daewoo Tico',
#  'Daewoo Nubira',
#  'Daewoo Tacuma',
#  'Daewoo Nexia',
#  'Daewoo Matiz',
#  'DAF FT Series',
#  'DAF FA Series',
#  'Daihatsu Charade',
#  'Daihatsu Sirion',
#  'Daihatsu Cuore',
#  'Daihatsu Terios',
#  'Daihatsu Gran Move',
#  'Dodge Caravan',
#  'Dodge Caliber',
#  'Fiat Punto',
#  'Fiat Bravo',
#  'Fiat Ducato',
#  'Fiat Ulysse',
#  'Fiat Multipla',
#  'Fiat Brava',
#  'Fiat Doblo',
#  'Fiat Stilo',
#  'Fiat Seicento',
#  'Fiat Tipo',
#  'Fiat Marea',
#  'Fiat Scudo',
#  'Fiat Tempra',
#  'Fiat Idea',
#  'Fiat Cinquecento',
#  'Fiat Croma',
#  'Fiat Qubo',
#  'Fiat Panda',
#  'Fiat Sedici',
#  'Fiat Linea',
#  'Ford Fiesta',
#  'Ford Focus',
#  'Ford Transit',
#  'Ford Orion',
#  'Ford Focus C-Max',
#  'Ford Mondeo',
#  'Ford KA',
#  'Ford Escort',
#  'Ford Puma',
#  'Ford Tourneo Connect',
#  'Ford Cougar',
#  'Ford Sierra',
#  'Ford Fusion',
#  'Ford Galaxy',
#  'Ford Ranger',
#  'Transit',
#  'Ford Kuga',
#  'Ford USA Mustang',
#  'GM Daewoo Kalos',
#  'Great Wall Voleex C30',
#  'Great Wall Voleex C10',
#  'Great Wall Hover',
#  'Honda Jazz',
#  'Honda CR-V',
#  'Honda Accord',
#  'Honda Civic',
#  'Honda HRV',
#  'Honda FR-V',
#  'Honda CB',
#  'Honda Stream',
#  'Honda VFR',
#  'Honda PCX',
#  'Honda Prelude',
#  'Honda CBR',
#  'Hyundai i10',
#  'Hyundai Santa Fe',
#  'Hyundai Accent',
#  'Hyundai Galloper',
#  'Hyundai Coupe',
#  'Hyundai Matrix',
#  'Hyundai i30',
#  'Hyundai Getz',
#  'Hyundai Atos',
#  'Hyundai Trajet',
#  'Hyundai ix35',
#  'Hyundai Grandeur',
#  'Hyundai Lantra/Elantra',
#  'Hyundai Terracan',
#  'Hyundai Santamo',
#  'Hyundai Elantra',
#  'Hyundai Tucson',
#  'Hyundai Sonata',
#  'Hyundai HD Series',
#  'Hyundai i20',
#  'Infiniti FX',
#  'Iveco Daily',
#  'Iveco TurboDaily',
#  'Jaguar X-Type',
#  'Jaguar XF',
#  'Jaguar XJ',
#  'Jeep Grand Cherokee',
#  'Jeep Cherokee',
#  'Kawasaki Z',
#  'Kia Carens',
#  "Kia Cee'd/Pro-cee'd",
#  'Kia Rio',
#  'Kia Sorento',
#  'Kia Sephia',
#  'Kia Magentis',
#  'Kia Carnival',
#  'Kia Sportage',
#  'Kia Visto',
#  'Kia Clarus',
#  'Kia Picanto',
#  'Kia Soul',
#  "Cee'd/Pro-cee'd",
#  'Lada 1200 - 1500',
#  'Lada Niva',
#  'Lancia Lybra',
#  'Lancia Zeta',
#  'Lancia Kappa',
#  'Lancia Ypsilon',
#  'Lancia Phedra',
#  'Lancia Y',
#  'Land Rover Freelander',
#  'Land Rover Discovery',
#  'Land Rover Range Rover Evoque',
#  'Land Rover Range Rover',
#  'Lexus GX',
#  'Lexus IS-200',
#  'Lexus RX',
#  'Lexus LS-400',
#  'Maserati Gran Turismo',
#  'Mazda Demio',
#  'Mazda 6',
#  'Mazda 323',
#  'Mazda 2',
#  'Mazda 3',
#  'Mazda Premacy',
#  'Mazda 5',
#  'Mazda MX-6',
#  'Mazda 626',
#  'Mazda Xedos-6',
#  'Mazda MPV',
#  'Mazda Tribute',
#  'Mazda 121',
#  'Mazda CX-7',
#  'Mercedes Body 211 E Class',
#  'Mercedes Body 210 E Class',
#  'Mercedes Body 638 Vito',
#  'Mercedes Body 124 E Class',
#  'Mercedes Body 202 C Class',
#  'Mercedes Body 163 M Class',
#  'Mercedes Body 168 A Class',
#  'Mercedes Body 203 C Class',
#  'Mercedes Body 201',
#  'Mercedes Series 600 Van',
#  'Mercedes Body 204 C Class',
#  'Mercedes Body 245 B Class',
#  'Mercedes SLK Class Body R171',
#  'Mercedes Sprinter Body 906',
#  'Mercedes Body X164 GL Class',
#  'Mercedes Body 129 SL',
#  'Mercedes Body 169 A Class',
#  'Mercedes Sprinter Body 904',
#  'Mercedes Body 212 E Class',
#  'Mercedes Body W246 B Class',
#  'Mercedes Sprinter Body 902',
#  'Mercedes Body C209 CLK Class',
#  'Mercedes Sprinter Body 903',
#  'Mercedes Body 220 S Class',
#  'Mercedes ML Class Body W166',
#  'Mercedes CLS Class Body W219',
#  'Mercedes Vito Body 639',
#  'Mercedes CLA Class Body C117',
#  'Body 163 M Class',
#  'Mercedes Body 208 CLK',
#  'Mercedes Body 221 S Class',
#  'Mercedes Sprinter Body 905',
#  'Mercedes Body 126',
#  'Body 170 SLK',
#  'Mercedes Body 463 G Class',
#  'Mercedes Sprinter Body 901',
#  'Mercedes Body W164 ML Class',
#  'Mercedes Body 251 R Class',
#  'Mercedes C Class Body W205',
#  'Mercedes Body 170 SLK',
#  'Mercedes S Class Body C217',
#  'Mercedes S Class Body W222',
#  'Mercedes Truck Atego',
#  'Mercedes Truck Actros',
#  'Mercedes Truck 1000 Series',
#  'MG F',
#  'Mini Cooper',
#  'Mini One',
#  'Mini One ECO',
#  'Mitsubishi Outlander',
#  'Mitsubishi Space Star',
#  'Mitsubishi Carisma',
#  'Mitsubishi Galant',
#  'Mitsubishi Delica',
#  'Mitsubishi Lancer',
#  'Mitsubishi Colt',
#  'Mitsubishi Space Runner',
#  'Mitsubishi Space Wagon',
#  'Mitsubishi Pajero',
#  'Mitsubishi Grandis',
#  'NA',
#  'Nissan Primera',
#  'Nissan Almera Tino',
#  'Nissan Micra',
#  'Nissan Almera',
#  'Nissan Terrano II',
#  'Nissan Note',
#  'Nissan Trade',
#  'Nissan Qashqai',
#  'Nissan X-Trail',
#  'Nissan Murano',
#  'Nissan Juke',
#  'Nissan Terrano',
#  'Nissan Serena',
#  'Nissan Versa',
#  'Nissan Pixo',
#  'Nissan Patrol',
#  'Nissan Pathfinder',
#  'Opel Astra',
#  'Opel Antara',
#  'Opel Vectra',
#  'Opel Corsa',
#  'Opel Zafira',
#  'Opel Frontera',
#  'Opel Rekord',
#  'Opel Omega',
#  'Opel Tigra',
#  'Opel Meriva',
#  'Opel Vivaro',
#  'Astra F/G',
#  'Opel Agila',
#  'Opel Kadett',
#  'Opel Signum',
#  'Opel Corsa Combo',
#  'Opel Insignia',
#  'Opel Mokka',
#  'Opel Combo',
#  'Vectra',
#  'Opel Calibra',
#  'Peugeot 206',
#  'Peugeot 306',
#  'Peugeot 405',
#  'Peugeot Expert',
#  'Peugeot 307',
#  'Peugeot 107',
#  'Peugeot 207',
#  'Peugeot Partner',
#  'Peugeot Bipper',
#  'Peugeot 407',
#  'Peugeot 406',
#  'Peugeot 106',
#  'Peugeot 308',
#  'Peugeot 4007',
#  'Peugeot 607',
#  'Peugeot 1007',
#  'Peugeot 508',
#  'Peugeot 806',
#  'Peugeot 309',
#  'Peugeot 208',
#  'Peugeot 205',
#  'Peugeot 301',
#  'Piaggio Liberty',
#  'Piaggio X',
#  'Porsche Cayman',
#  'Porsche Cayenne',
#  'Renault Kangoo',
#  'Renault Scenic',
#  'Renault Megane',
#  'Renault Clio',
#  'Renault Laguna',
#  'Renault Fluence',
#  'Renault 19',
#  'Renault Espace',
#  'Renault Twingo',
#  'Renault Master',
#  'Renault Modus',
#  'Renault Express',
#  'Renault Vel Satis',
#  'Renault Captur',
#  'Renault V.I Premium',
#  'Rover Series 400',
#  'Rover Series 25',
#  'Rover Series 200',
#  'Rover Series 600',
#  'Saab 9-3',
#  'Saab 9-5',
#  'Saab 900',
#  'Saab 9000',
#  'Scania R Class',
#  'Seat Cordoba',
#  'Seat Altea',
#  'Seat Ibiza',
#  'Seat Toledo',
#  'Seat Leon',
#  'Seat Alhambra',
#  'Skoda Fabia',
#  'Skoda Octavia',
#  'Skoda Felicia',
#  'Skoda Roomster',
#  'Skoda 105/120/130',
#  'Fabia',
#  'Skoda Rapid',
#  'Skoda Pickup',
#  'Skoda Citigo',
#  'Smart Fortwo',
#  'SsangYong Rexton',
#  'SsangYong Actyon',
#  'SsangYong Kyron',
#  'SsangYong Rodius',
#  'Subaru Outback',
#  'Subaru Forester',
#  'Subaru Impreza',
#  'Subaru Legacy',
#  'Subaru Domingo',
#  'Subaru Justy',
#  'Suzuki Grand Vitara',
#  'Suzuki Burgman',
#  'Suzuki Splash',
#  'Suzuki Vitara',
#  'Suzuki Swift',
#  'Suzuki Ignis',
#  'Suzuki Samurai',
#  'Suzuki Baleno',
#  'Suzuki Alto',
#  'Suzuki SX-4',
#  'Suzuki Liana',
#  'Suzuki Wagon R+',
#  'Toyota Aygo',
#  'Toyota Yaris',
#  'Toyota Auris',
#  'Toyota RAV-4',
#  'Toyota Corolla',
#  'Toyota Verso',
#  'Toyota Carina',
#  'Toyota Avensis',
#  'Toyota Celica',
#  'Toyota Paseo',
#  'Toyota HiLux',
#  'Toyota Avensis Verso',
#  'Toyota Land Cruiser',
#  'Toyota Prius',
#  'Volkswagen Golf',
#  'Volkswagen Vento',
#  'Volkswagen Polo',
#  'Volkswagen Passat',
#  'Volkswagen Bora',
#  'Volkswagen Sharan',
#  'Volkswagen Transporter',
#  'Volkswagen Touran',
#  'Volkswagen Tiguan',
#  'Volkswagen Lupo',
#  'Volkswagen Jetta',
#  'Volkswagen Caddy',
#  'Volkswagen Crafter',
#  'Volkswagen Phaeton',
#  'Volkswagen Touareg',
#  'Volvo Series 40',
#  'Volvo XC60',
#  'Volvo XC 70',
#  'Volvo S80',
#  'Volvo Series 60',
#  'Volvo V40',
#  'Volvo Series 50',
#  'Volvo Series 70',
#  'Volvo 850',
#  'Volvo C30',
#  'Volvo C70',
#  'Volvo Truck F Series',
#  'Yamaha YZF-R',
#  'Yamaha TTR']

# %% [markdown]
# Save them to Dynamo DB

# %%
for query in queries:
    persister.put(query)
